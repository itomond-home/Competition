# %%
import gc
import os
import json
import joblib
import random
import requests
import itertools

import scipy as sp
import numpy as np
import pandas as pd
from tqdm import tqdm
import lightgbm as lgb

pd.set_option('display.width', 1000)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.options.display.max_info_columns = 100000

import warnings; warnings.filterwarnings('ignore')

from itertools import combinations
from sklearn.model_selection import StratifiedKFold, train_test_split

# %% [markdown]
# # 学習と推論

# %% [markdown]
# ## 準備

# %%
# train = pd.read_csv('/content/drive/MyDrive/competition/Amex0824/data/train_all.csv')
train = pd.read_pickle("/content/drive/MyDrive/competition/Amex0824/data/df_train_all.pkl")

# %%
# test = pd.read_pickle("/content/drive/MyDrive/competition/Amex0824/data/df_test_all.pkl")

# %%
train_labels = pd.read_csv("/content/drive/MyDrive/competition/Amex0824/data/train_labels.csv")
train = pd.merge(train, train_labels, on="customer_ID")

# %%
class CFG:
    seed = 42
    n_folds = 5
    target = 'target'
    input_dir = ''

# %%
def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)

# %%
def amex_metric(y_true, y_pred):
    labels = np.transpose(np.array([y_true, y_pred]))
    labels = labels[labels[:, 1].argsort()[::-1]]
    weights = np.where(labels[:,0]==0, 20, 1)
    cut_vals = labels[np.cumsum(weights) <= int(0.04 * np.sum(weights))]
    top_four = np.sum(cut_vals[:,0]) / np.sum(labels[:,0])
    gini = [0,0]
    for i in [1,0]:
        labels = np.transpose(np.array([y_true, y_pred]))
        labels = labels[labels[:, i].argsort()[::-1]]
        weight = np.where(labels[:,0]==0, 20, 1)
        weight_random = np.cumsum(weight / np.sum(weight))
        total_pos = np.sum(labels[:, 0] *  weight)
        cum_pos_found = np.cumsum(labels[:, 0] * weight)
        lorentz = cum_pos_found / total_pos
        gini[i] = np.sum((lorentz - weight_random) * weight)
    return 0.5 * (gini[1]/gini[0] + top_four)

# %%
def amex_metric_np(preds, target):
    indices = np.argsort(preds)[::-1]
    preds, target = preds[indices], target[indices]
    weight = 20.0 - target * 19.0
    cum_norm_weight = (weight / weight.sum()).cumsum()
    four_pct_mask = cum_norm_weight <= 0.04
    d = np.sum(target[four_pct_mask]) / np.sum(target)
    weighted_target = target * weight
    lorentz = (weighted_target / weighted_target.sum()).cumsum()
    gini = ((lorentz - cum_norm_weight) * weight).sum()
    n_pos = np.sum(target)
    n_neg = target.shape[0] - n_pos
    gini_max = 10 * n_neg * (n_pos + 20 * n_neg - 19) / (n_pos + 20 * n_neg)
    g = gini / gini_max
    return 0.5 * (g + d)

# %%
def lgb_amex_metric(y_pred, y_true):
    y_true = y_true.get_label()
    return 'amex_metric', amex_metric(y_true, y_pred), True

# %% [markdown]
# ## モデル

# %%
def train_and_evaluate(train):
  # Get feature list
  features = [col for col in train.columns if col not in ['customer_ID', CFG.target]]
  models = []
  scores = 0.0
  params = {
      'objective': 'binary',
      'metric': "binary_logloss",
      'boosting': 'dart',
      'seed': CFG.seed,
      'num_leaves': 100,
      'learning_rate': 0.01,
      'feature_fraction': 0.20,
      'bagging_freq': 10,
      'bagging_fraction': 0.50,
      'lambda_l2': 2,
      'n_jobs': -1,
      'min_data_in_leaf': 40,
      'force_col_wise' : True
      }
  # Create a numpy array to store out of folds predictions
  oof_predictions = np.zeros(len(train))
  kfold = StratifiedKFold(n_splits = CFG.n_folds, shuffle = True, random_state = CFG.seed)
  for fold, (trn_ind, val_ind) in enumerate(kfold.split(train, train[CFG.target])):
    print('-'*50)
    print(f'Training fold {fold} with {len(features)} features...')
    x_train, x_val = train[features].iloc[trn_ind], train[features].iloc[val_ind]
    y_train, y_val = train[CFG.target].iloc[trn_ind], train[CFG.target].iloc[val_ind]
    lgb_train = lgb.Dataset(x_train, y_train)
    lgb_valid = lgb.Dataset(x_val, y_val)
    model = lgb.train(
        params = params,
        train_set = lgb_train,
        num_boost_round = 10500,
        valid_sets = [lgb_train, lgb_valid],
        early_stopping_rounds = 100,
        verbose_eval = 100,
        feval = lgb_amex_metric,
        )
    # validation データでの予測結果
    val_pred = model.predict(x_val)
    score = amex_metric(y_val, val_pred)
    print(f'Our fold {fold} CV score is {score}')

    scores += score / 5
    models.append(model)
    print("*" * 100)

  # 各 fold における Validation スコアの平均
  print(f"All fold average score : {scores:.4f}")
  return models

# %%
seed_everything(CFG.seed)
models = train_and_evaluate(train)
# Out:
# --------------------------------------------------
# Training fold 0 with 35 features...
# [100]	training's binary_logloss: 0.522018	training's amex_metric: 0.568333	valid_1's binary_logloss: 0.522169	valid_1's amex_metric: 0.565896
# [200]	training's binary_logloss: 0.514329	training's amex_metric: 0.56962	valid_1's binary_logloss: 0.514522	valid_1's amex_metric: 0.567111
# [300]	training's binary_logloss: 0.476866	training's amex_metric: 0.573754	valid_1's binary_logloss: 0.477156	valid_1's amex_metric: 0.570999
# [400]	training's binary_logloss: 0.459049	training's amex_metric: 0.578937	valid_1's binary_logloss: 0.459386	valid_1's amex_metric: 0.576087
# [500]	training's binary_logloss: 0.437665	training's amex_metric: 0.580922	valid_1's binary_logloss: 0.438065	valid_1's amex_metric: 0.578053
# [600]	training's binary_logloss: 0.424136	training's amex_metric: 0.582139	valid_1's binary_logloss: 0.424587	valid_1's amex_metric: 0.579192
# [700]	training's binary_logloss: 0.399012	training's amex_metric: 0.586209	valid_1's binary_logloss: 0.399563	valid_1's amex_metric: 0.583273
# [800]	training's binary_logloss: 0.382369	training's amex_metric: 0.588861	valid_1's binary_logloss: 0.382994	valid_1's amex_metric: 0.585887
# [900]	training's binary_logloss: 0.368224	training's amex_metric: 0.593899	valid_1's binary_logloss: 0.368934	valid_1's amex_metric: 0.590591
# [1000]	training's binary_logloss: 0.362933	training's amex_metric: 0.59574	valid_1's binary_logloss: 0.363676	valid_1's amex_metric: 0.592565
# [1100]	training's binary_logloss: 0.353626	training's amex_metric: 0.597601	valid_1's binary_logloss: 0.354445	valid_1's amex_metric: 0.594373
# [1200]	training's binary_logloss: 0.350373	training's amex_metric: 0.600443	valid_1's binary_logloss: 0.351234	valid_1's amex_metric: 0.596926
# [1300]	training's binary_logloss: 0.347101	training's amex_metric: 0.601973	valid_1's binary_logloss: 0.348002	valid_1's amex_metric: 0.598129
# [1400]	training's binary_logloss: 0.343721	training's amex_metric: 0.60263	valid_1's binary_logloss: 0.344674	valid_1's amex_metric: 0.598454
# [1500]	training's binary_logloss: 0.342291	training's amex_metric: 0.602918	valid_1's binary_logloss: 0.343269	valid_1's amex_metric: 0.598824
# [1600]	training's binary_logloss: 0.334941	training's amex_metric: 0.607644	valid_1's binary_logloss: 0.336008	valid_1's amex_metric: 0.603338
# [1700]	training's binary_logloss: 0.331826	training's amex_metric: 0.610793	valid_1's binary_logloss: 0.332942	valid_1's amex_metric: 0.606664
# [1800]	training's binary_logloss: 0.330035	training's amex_metric: 0.613455	valid_1's binary_logloss: 0.331185	valid_1's amex_metric: 0.609374
# [1900]	training's binary_logloss: 0.327455	training's amex_metric: 0.615718	valid_1's binary_logloss: 0.328655	valid_1's amex_metric: 0.611495
# [2000]	training's binary_logloss: 0.324706	training's amex_metric: 0.617515	valid_1's binary_logloss: 0.325964	valid_1's amex_metric: 0.613215
# [2100]	training's binary_logloss: 0.323431	training's amex_metric: 0.619101	valid_1's binary_logloss: 0.324724	valid_1's amex_metric: 0.614968
# [2200]	training's binary_logloss: 0.322571	training's amex_metric: 0.62017	valid_1's binary_logloss: 0.323888	valid_1's amex_metric: 0.616022
# [2300]	training's binary_logloss: 0.32069	training's amex_metric: 0.621595	valid_1's binary_logloss: 0.322057	valid_1's amex_metric: 0.617419
# [2400]	training's binary_logloss: 0.319492	training's amex_metric: 0.623168	valid_1's binary_logloss: 0.320891	valid_1's amex_metric: 0.619146
# [2500]	training's binary_logloss: 0.318084	training's amex_metric: 0.624601	valid_1's binary_logloss: 0.319523	valid_1's amex_metric: 0.62073
# [2600]	training's binary_logloss: 0.316674	training's amex_metric: 0.625835	valid_1's binary_logloss: 0.318154	valid_1's amex_metric: 0.621826
# [2700]	training's binary_logloss: 0.314918	training's amex_metric: 0.627461	valid_1's binary_logloss: 0.316443	valid_1's amex_metric: 0.623085
# [2800]	training's binary_logloss: 0.314298	training's amex_metric: 0.628444	valid_1's binary_logloss: 0.315855	valid_1's amex_metric: 0.623985
# [2900]	training's binary_logloss: 0.313151	training's amex_metric: 0.629484	valid_1's binary_logloss: 0.31476	valid_1's amex_metric: 0.6249
# [3000]	training's binary_logloss: 0.312082	training's amex_metric: 0.630245	valid_1's binary_logloss: 0.313742	valid_1's amex_metric: 0.625753
# [3100]	training's binary_logloss: 0.311177	training's amex_metric: 0.631196	valid_1's binary_logloss: 0.312876	valid_1's amex_metric: 0.626763
# [3200]	training's binary_logloss: 0.310484	training's amex_metric: 0.63201	valid_1's binary_logloss: 0.312228	valid_1's amex_metric: 0.627492
# [3300]	training's binary_logloss: 0.309762	training's amex_metric: 0.632776	valid_1's binary_logloss: 0.311546	valid_1's amex_metric: 0.628004
# [3400]	training's binary_logloss: 0.308839	training's amex_metric: 0.633634	valid_1's binary_logloss: 0.310674	valid_1's amex_metric: 0.629026
# [3500]	training's binary_logloss: 0.307936	training's amex_metric: 0.634645	valid_1's binary_logloss: 0.309817	valid_1's amex_metric: 0.629847
# [3600]	training's binary_logloss: 0.30737	training's amex_metric: 0.635616	valid_1's binary_logloss: 0.309288	valid_1's amex_metric: 0.630558
# [3700]	training's binary_logloss: 0.306479	training's amex_metric: 0.636285	valid_1's binary_logloss: 0.308455	valid_1's amex_metric: 0.631135
# [3800]	training's binary_logloss: 0.305875	training's amex_metric: 0.637208	valid_1's binary_logloss: 0.307891	valid_1's amex_metric: 0.63202
# [3900]	training's binary_logloss: 0.305439	training's amex_metric: 0.637979	valid_1's binary_logloss: 0.30749	valid_1's amex_metric: 0.632875
# [4000]	training's binary_logloss: 0.30493	training's amex_metric: 0.638712	valid_1's binary_logloss: 0.307017	valid_1's amex_metric: 0.633671
# [4100]	training's binary_logloss: 0.304371	training's amex_metric: 0.639414	valid_1's binary_logloss: 0.306502	valid_1's amex_metric: 0.634438
# [4200]	training's binary_logloss: 0.303613	training's amex_metric: 0.640328	valid_1's binary_logloss: 0.305797	valid_1's amex_metric: 0.635239
# [4300]	training's binary_logloss: 0.302995	training's amex_metric: 0.640952	valid_1's binary_logloss: 0.305227	valid_1's amex_metric: 0.635895
# [4400]	training's binary_logloss: 0.302816	training's amex_metric: 0.641531	valid_1's binary_logloss: 0.305068	valid_1's amex_metric: 0.63632
# [4500]	training's binary_logloss: 0.302298	training's amex_metric: 0.642159	valid_1's binary_logloss: 0.304596	valid_1's amex_metric: 0.636804
# [4600]	training's binary_logloss: 0.301463	training's amex_metric: 0.642822	valid_1's binary_logloss: 0.303823	valid_1's amex_metric: 0.637456
# [4700]	training's binary_logloss: 0.301083	training's amex_metric: 0.64361	valid_1's binary_logloss: 0.303476	valid_1's amex_metric: 0.6381
# [4800]	training's binary_logloss: 0.300797	training's amex_metric: 0.644176	valid_1's binary_logloss: 0.303231	valid_1's amex_metric: 0.638692
# [4900]	training's binary_logloss: 0.30036	training's amex_metric: 0.644834	valid_1's binary_logloss: 0.302844	valid_1's amex_metric: 0.639247
# [5000]	training's binary_logloss: 0.300122	training's amex_metric: 0.645438	valid_1's binary_logloss: 0.302643	valid_1's amex_metric: 0.639804
# [5100]	training's binary_logloss: 0.299908	training's amex_metric: 0.646033	valid_1's binary_logloss: 0.302466	valid_1's amex_metric: 0.640327
# [5200]	training's binary_logloss: 0.299357	training's amex_metric: 0.646671	valid_1's binary_logloss: 0.301967	valid_1's amex_metric: 0.640888
# [5300]	training's binary_logloss: 0.299132	training's amex_metric: 0.647216	valid_1's binary_logloss: 0.301768	valid_1's amex_metric: 0.641323
# [5400]	training's binary_logloss: 0.298711	training's amex_metric: 0.647772	valid_1's binary_logloss: 0.301396	valid_1's amex_metric: 0.641778
# [5500]	training's binary_logloss: 0.298269	training's amex_metric: 0.648357	valid_1's binary_logloss: 0.301003	valid_1's amex_metric: 0.642292
# [5600]	training's binary_logloss: 0.297962	training's amex_metric: 0.648773	valid_1's binary_logloss: 0.300737	valid_1's amex_metric: 0.642662
# [5700]	training's binary_logloss: 0.297734	training's amex_metric: 0.649238	valid_1's binary_logloss: 0.300556	valid_1's amex_metric: 0.643068
# [5800]	training's binary_logloss: 0.297559	training's amex_metric: 0.649706	valid_1's binary_logloss: 0.300413	valid_1's amex_metric: 0.643381
# [5900]	training's binary_logloss: 0.297221	training's amex_metric: 0.650206	valid_1's binary_logloss: 0.300124	valid_1's amex_metric: 0.643932
# [6000]	training's binary_logloss: 0.297012	training's amex_metric: 0.65068	valid_1's binary_logloss: 0.299942	valid_1's amex_metric: 0.644233
# [6100]	training's binary_logloss: 0.296765	training's amex_metric: 0.651122	valid_1's binary_logloss: 0.299734	valid_1's amex_metric: 0.644498
# [6200]	training's binary_logloss: 0.296455	training's amex_metric: 0.651594	valid_1's binary_logloss: 0.299463	valid_1's amex_metric: 0.644858
# [6300]	training's binary_logloss: 0.296139	training's amex_metric: 0.652062	valid_1's binary_logloss: 0.299194	valid_1's amex_metric: 0.645321
# [6400]	training's binary_logloss: 0.295919	training's amex_metric: 0.652565	valid_1's binary_logloss: 0.299011	valid_1's amex_metric: 0.645798
# [6500]	training's binary_logloss: 0.295593	training's amex_metric: 0.652994	valid_1's binary_logloss: 0.298733	valid_1's amex_metric: 0.646107
# [6600]	training's binary_logloss: 0.295157	training's amex_metric: 0.653499	valid_1's binary_logloss: 0.298347	valid_1's amex_metric: 0.646642
# [6700]	training's binary_logloss: 0.294883	training's amex_metric: 0.653998	valid_1's binary_logloss: 0.298122	valid_1's amex_metric: 0.647005
# [6800]	training's binary_logloss: 0.29447	training's amex_metric: 0.654486	valid_1's binary_logloss: 0.297762	valid_1's amex_metric: 0.647531
# [6900]	training's binary_logloss: 0.294196	training's amex_metric: 0.655018	valid_1's binary_logloss: 0.297537	valid_1's amex_metric: 0.647954
# [7000]	training's binary_logloss: 0.293906	training's amex_metric: 0.655454	valid_1's binary_logloss: 0.297294	valid_1's amex_metric: 0.648178
# [7100]	training's binary_logloss: 0.293504	training's amex_metric: 0.656035	valid_1's binary_logloss: 0.296949	valid_1's amex_metric: 0.648582
# [7200]	training's binary_logloss: 0.2932	training's amex_metric: 0.656638	valid_1's binary_logloss: 0.296695	valid_1's amex_metric: 0.648951
# [7300]	training's binary_logloss: 0.292952	training's amex_metric: 0.657185	valid_1's binary_logloss: 0.296493	valid_1's amex_metric: 0.649522
# [7400]	training's binary_logloss: 0.292747	training's amex_metric: 0.657693	valid_1's binary_logloss: 0.296333	valid_1's amex_metric: 0.649886
# [7500]	training's binary_logloss: 0.292474	training's amex_metric: 0.658247	valid_1's binary_logloss: 0.296107	valid_1's amex_metric: 0.650269
# [7600]	training's binary_logloss: 0.292299	training's amex_metric: 0.658682	valid_1's binary_logloss: 0.295977	valid_1's amex_metric: 0.650698
# [7700]	training's binary_logloss: 0.292096	training's amex_metric: 0.659152	valid_1's binary_logloss: 0.295813	valid_1's amex_metric: 0.650817
# [7800]	training's binary_logloss: 0.291819	training's amex_metric: 0.659656	valid_1's binary_logloss: 0.295572	valid_1's amex_metric: 0.651263
# [7900]	training's binary_logloss: 0.291577	training's amex_metric: 0.660095	valid_1's binary_logloss: 0.295372	valid_1's amex_metric: 0.651513
# [8000]	training's binary_logloss: 0.291285	training's amex_metric: 0.660643	valid_1's binary_logloss: 0.29514	valid_1's amex_metric: 0.651884
# [8100]	training's binary_logloss: 0.291093	training's amex_metric: 0.661139	valid_1's binary_logloss: 0.294984	valid_1's amex_metric: 0.652428
# [8200]	training's binary_logloss: 0.290772	training's amex_metric: 0.661706	valid_1's binary_logloss: 0.294716	valid_1's amex_metric: 0.652693
# [8300]	training's binary_logloss: 0.290616	training's amex_metric: 0.662118	valid_1's binary_logloss: 0.294596	valid_1's amex_metric: 0.652991
# [8400]	training's binary_logloss: 0.290433	training's amex_metric: 0.662652	valid_1's binary_logloss: 0.294446	valid_1's amex_metric: 0.653422
# [8500]	training's binary_logloss: 0.290209	training's amex_metric: 0.663052	valid_1's binary_logloss: 0.294259	valid_1's amex_metric: 0.653768
# [8600]	training's binary_logloss: 0.28997	training's amex_metric: 0.663521	valid_1's binary_logloss: 0.294065	valid_1's amex_metric: 0.654056
# [8700]	training's binary_logloss: 0.289604	training's amex_metric: 0.664072	valid_1's binary_logloss: 0.29376	valid_1's amex_metric: 0.654569
# [8800]	training's binary_logloss: 0.289406	training's amex_metric: 0.664509	valid_1's binary_logloss: 0.293603	valid_1's amex_metric: 0.654904
# [8900]	training's binary_logloss: 0.289227	training's amex_metric: 0.664941	valid_1's binary_logloss: 0.293469	valid_1's amex_metric: 0.65523
# [9000]	training's binary_logloss: 0.288974	training's amex_metric: 0.665281	valid_1's binary_logloss: 0.293268	valid_1's amex_metric: 0.655459
# [9100]	training's binary_logloss: 0.288789	training's amex_metric: 0.665655	valid_1's binary_logloss: 0.293118	valid_1's amex_metric: 0.655879
# [9200]	training's binary_logloss: 0.288481	training's amex_metric: 0.666146	valid_1's binary_logloss: 0.29287	valid_1's amex_metric: 0.656218
# [9300]	training's binary_logloss: 0.288271	training's amex_metric: 0.666492	valid_1's binary_logloss: 0.292707	valid_1's amex_metric: 0.65653
# [9400]	training's binary_logloss: 0.288164	training's amex_metric: 0.666916	valid_1's binary_logloss: 0.292625	valid_1's amex_metric: 0.656861
# [9500]	training's binary_logloss: 0.287874	training's amex_metric: 0.667284	valid_1's binary_logloss: 0.292389	valid_1's amex_metric: 0.657067
# [9600]	training's binary_logloss: 0.287664	training's amex_metric: 0.667792	valid_1's binary_logloss: 0.292224	valid_1's amex_metric: 0.65745
# [9700]	training's binary_logloss: 0.287423	training's amex_metric: 0.668213	valid_1's binary_logloss: 0.292027	valid_1's amex_metric: 0.657904
# [9800]	training's binary_logloss: 0.287222	training's amex_metric: 0.668677	valid_1's binary_logloss: 0.291878	valid_1's amex_metric: 0.658179
# [9900]	training's binary_logloss: 0.287011	training's amex_metric: 0.669058	valid_1's binary_logloss: 0.291712	valid_1's amex_metric: 0.658535
# [10000]	training's binary_logloss: 0.286821	training's amex_metric: 0.669421	valid_1's binary_logloss: 0.291567	valid_1's amex_metric: 0.658803
# [10100]	training's binary_logloss: 0.286754	training's amex_metric: 0.669775	valid_1's binary_logloss: 0.291526	valid_1's amex_metric: 0.659059
# [10200]	training's binary_logloss: 0.286564	training's amex_metric: 0.670081	valid_1's binary_logloss: 0.291379	valid_1's amex_metric: 0.659285
# [10300]	training's binary_logloss: 0.286372	training's amex_metric: 0.670512	valid_1's binary_logloss: 0.291235	valid_1's amex_metric: 0.659631
# [10400]	training's binary_logloss: 0.2862	training's amex_metric: 0.671012	valid_1's binary_logloss: 0.291106	valid_1's amex_metric: 0.66
# [10500]	training's binary_logloss: 0.285985	training's amex_metric: 0.671382	valid_1's binary_logloss: 0.290943	valid_1's amex_metric: 0.660288
# Our fold 0 CV score is 0.6602880520216607
# ****************************************************************************************************
# --------------------------------------------------
# Training fold 1 with 35 features...
# [100]	training's binary_logloss: 0.522118	training's amex_metric: 0.56763	valid_1's binary_logloss: 0.522099	valid_1's amex_metric: 0.566721
# [200]	training's binary_logloss: 0.514459	training's amex_metric: 0.569018	valid_1's binary_logloss: 0.514443	valid_1's amex_metric: 0.568444
# [300]	training's binary_logloss: 0.477065	training's amex_metric: 0.572963	valid_1's binary_logloss: 0.477046	valid_1's amex_metric: 0.572345
# [400]	training's binary_logloss: 0.459205	training's amex_metric: 0.578103	valid_1's binary_logloss: 0.459178	valid_1's amex_metric: 0.577421
# [500]	training's binary_logloss: 0.437838	training's amex_metric: 0.580283	valid_1's binary_logloss: 0.43781	valid_1's amex_metric: 0.579738
# [600]	training's binary_logloss: 0.424341	training's amex_metric: 0.58153	valid_1's binary_logloss: 0.424333	valid_1's amex_metric: 0.580943
# [700]	training's binary_logloss: 0.399271	training's amex_metric: 0.585449	valid_1's binary_logloss: 0.399297	valid_1's amex_metric: 0.584871
# [800]	training's binary_logloss: 0.382536	training's amex_metric: 0.588096	valid_1's binary_logloss: 0.382592	valid_1's amex_metric: 0.587662
# [900]	training's binary_logloss: 0.368254	training's amex_metric: 0.593429	valid_1's binary_logloss: 0.368327	valid_1's amex_metric: 0.592663
# [1000]	training's binary_logloss: 0.362967	training's amex_metric: 0.59545	valid_1's binary_logloss: 0.363062	valid_1's amex_metric: 0.5946
# [1100]	training's binary_logloss: 0.353583	training's amex_metric: 0.597586	valid_1's binary_logloss: 0.353724	valid_1's amex_metric: 0.596631
# [1200]	training's binary_logloss: 0.350335	training's amex_metric: 0.600313	valid_1's binary_logloss: 0.350482	valid_1's amex_metric: 0.599371
# [1300]	training's binary_logloss: 0.34712	training's amex_metric: 0.601479	valid_1's binary_logloss: 0.347283	valid_1's amex_metric: 0.600803
# [1400]	training's binary_logloss: 0.343795	training's amex_metric: 0.602012	valid_1's binary_logloss: 0.343976	valid_1's amex_metric: 0.601199
# [1500]	training's binary_logloss: 0.342405	training's amex_metric: 0.602242	valid_1's binary_logloss: 0.342609	valid_1's amex_metric: 0.601517
# [1600]	training's binary_logloss: 0.335104	training's amex_metric: 0.606828	valid_1's binary_logloss: 0.335328	valid_1's amex_metric: 0.606066

# %%
del train
gc.collect()

# %%
test = pd.read_csv('/content/drive/MyDrive/competition/Amex0824/data/test_all.csv')
# test データと同じ長さですべての要素が 0 の配列を用意
preds = np.zeros(len(test))

# 各モデルで推論
for model in models:
    pred = model.predict(test, num_iteration=model.best_iteration)
    preds += pred / len(models)
    
test_df = pd.DataFrame({'customer_ID': test['customer_ID'], 'prediction': preds})
test_df.to_csv(f'test_lgbm_baseline_{CFG.n_folds}fold_seed{CFG.seed}.csv', index = False)
